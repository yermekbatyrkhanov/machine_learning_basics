# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\yerme\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\yerme\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\yerme\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yerme\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yerme\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\yerme\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\yerme\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yerme\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yerme\anaconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yerme\anaconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\yerme\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from statistics import mean

# %%
import numpy as np

# %%
xs = np.array([1,2,3,4,5,6], dtype=np.float64)

# %%
ys = np.array([5,4,6,5,6,7], dtype=np.float64)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(xs, ys)

# %%
plt.show()

# %%
def best_fit_slope_and_intercept(xs,ys):
    m = ( ( mean(xs) * mean(ys) ) - mean(xs*ys) ) / ( (mean(xs)**2) - mean(xs**2))
    b = mean(ys) - m*mean(xs)
    return m, b

# %%
m,b = best_fit_slope_and_intercept (xs,ys)
print(m,b)
# Out:
# 0.42857142857142866 4.0

# %%
regression_line = [(m*x)+b for x in xs]

# %%
from matplotlib import style

# %%
plt.scatter(xs, ys)

# %%
plt.plot(xs, regression_line)

# %%
plt.show()

# %%
def squared_error(ys_orig, ys_line):
    return sum( (ys_line-ys_orig)**2 )

# %%
def coefficient_of_determination(ys_orig, ys_line):
    y_mean_line = [mean(ys_orig) for y in ys_orig]
    squared_error_regr = squared_error(ys_orig, ys_line)
    squared_error_y_mean = squared_error(ys_orig, y_mean_line)
    return 1 - (squared_error_regr / squared_error_y_mean)

# %%
r_squared = coefficient_of_determination(ys, regression_line)
print(r_squared)
# Out:
# 0.5844155844155845
